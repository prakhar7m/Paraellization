# %% [markdown]
# ## Assignment - Single Machine Parallelization

# %% [markdown]
# In this assignment we will be investigating the Enron email corpus from the 2002 Federal Energy Regulatory Commission (FERB) investigation.  This corpus of emails is still used to train AI on topics related to corporate communication, as this is one of the few public datasets available. Though there are AI ethics questions if the data is used for language purposes without proper precautions. [Read this article](https://qz.com/work/1546565/the-emails-that-brought-down-enron-still-shape-our-daily-lives/) to learn more about the dataset and its implications for AI.

# %% [markdown]
# Start off by choosing the `ml.m5.xlarge` instance as your kernel. Then start conducting the lab.

# %% [markdown]
# ---

# %% [markdown]
# ### Task 0: Download dataset and explore it

# %% [markdown]
# The research dataset is located here, maintained by Carnegie Mellon University, https://www.cs.cmu.edu/~enron/. Though due to its size we have created a smaller version on S3. Follow these steps to get the file:
#
# 1. Copy the file from the class's public S3 bucket into your own S3 bucket. You must change the bucket name to yours with your net id. `aws s3 cp s3://bigdatateaching/enron/maildir.zip s3://[NET_ID]-labdata`

# %%
aws s3 cp s3://bigdatateaching/enron/maildir.zip s3://pm1178-labdata
# Out:
#   File "<ipython-input-1-b53f475c3241>", line 1
#     aws s3 cp s3://bigdatateaching/enron/maildir.zip s3://pm1178-labdata
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 2. Copy the file from your own S3 bucket to SageMaker. Use the boto3 package for this. This will palce the `maildir` directory from the zip file into the main folder of your git repository.

# %%
import boto3
my_bucket = 'pm1178-labdata'
my_file = 'maildir.zip'

s3client = boto3.client('s3')
#s3.download_file('BUCKET_NAME', 'OBJECT_NAME', 'FILE_NAME')
s3client.download_file(my_bucket, my_file, 'maildir.zip')

# %% [markdown]
# 3. Run the following command in a new cell to unzip the directory. This could take a while, there are almost 80,000 files!!

# %%
# !conda install -y -c conda-forge unzip
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !unzip ./maildir.zip
# Out:
# Archive:  ./maildir.zip
#    creating: maildir/
#    creating: maildir/allen-p/
#    creating: maildir/allen-p/all_documents/
#    creating: maildir/allen-p/contacts/
#    creating: maildir/allen-p/deleted_items/
#    creating: maildir/allen-p/discussion_threads/
#    creating: maildir/allen-p/inbox/
#    creating: maildir/allen-p/inbox/.ipynb_checkpoints/
#   inflating: maildir/allen-p/inbox/.ipynb_checkpoints/14_-checkpoint
#   inflating: maildir/allen-p/inbox/10_
#   inflating: maildir/allen-p/inbox/11_
#   inflating: maildir/allen-p/inbox/12_
#   inflating: maildir/allen-p/inbox/13_
#   inflating: maildir/allen-p/inbox/14_
#   inflating: maildir/allen-p/inbox/15_
#   inflating: maildir/allen-p/inbox/16_
#   inflating: maildir/allen-p/inbox/17_
#   inflating: maildir/allen-p/inbox/18_
#   inflating: maildir/allen-p/inbox/19_
#   inflating: maildir/allen-p/inbox/1_
#   inflating: maildir/allen-p/inbox/20_
#   inflating: maildir/allen-p/inbox/21_
#   inflating: maildir/allen-p/inbox/22_
#   inflating: maildir/allen-p/inbox/23_
#   inflating: maildir/allen-p/inbox/24_
#   inflating: maildir/allen-p/inbox/25_
#   inflating: maildir/allen-p/inbox/26_
#   inflating: maildir/allen-p/inbox/27_
#   inflating: maildir/allen-p/inbox/28_
#   inflating: maildir/allen-p/inbox/29_
#   inflating: maildir/allen-p/inbox/2_
#   inflating: maildir/allen-p/inbox/30_
#   inflating: maildir/allen-p/inbox/31_
#   inflating: maildir/allen-p/inbox/32_
#   inflating: maildir/allen-p/inbox/33_
#   inflating: maildir/allen-p/inbox/34_
#   inflating: maildir/allen-p/inbox/35_
#   inflating: maildir/allen-p/inbox/36_
#   inflating: maildir/allen-p/inbox/37_
#   inflating: maildir/allen-p/inbox/38_
#   inflating: maildir/allen-p/inbox/39_
#   inflating: maildir/allen-p/inbox/3_
#   inflating: maildir/allen-p/inbox/40_
#   inflating: maildir/allen-p/inbox/41_
#   inflating: maildir/allen-p/inbox/42_
#   inflating: maildir/allen-p/inbox/43_
#   inflating: maildir/allen-p/inbox/44_
#   inflating: maildir/allen-p/inbox/45_
#   inflating: maildir/allen-p/inbox/4_
#   inflating: maildir/allen-p/inbox/5_
#   inflating: maildir/allen-p/inbox/62_
#   inflating: maildir/allen-p/inbox/63_
#   inflating: maildir/allen-p/inbox/64_
#   inflating: maildir/allen-p/inbox/65_
#   inflating: maildir/allen-p/inbox/66_
#   inflating: maildir/allen-p/inbox/67_
#   inflating: maildir/allen-p/inbox/68_
#   inflating: maildir/allen-p/inbox/69_
#   inflating: maildir/allen-p/inbox/6_
#   inflating: maildir/allen-p/inbox/70_
#   inflating: maildir/allen-p/inbox/71_
#   inflating: maildir/allen-p/inbox/72_
#   inflating: maildir/allen-p/inbox/73_
#   inflating: maildir/allen-p/inbox/74_
#   inflating: maildir/allen-p/inbox/75_
#   inflating: maildir/allen-p/inbox/78_
#   inflating: maildir/allen-p/inbox/79_
#   inflating: maildir/allen-p/inbox/7_
#   inflating: maildir/allen-p/inbox/83_
#   inflating: maildir/allen-p/inbox/84_
#   inflating: maildir/allen-p/inbox/85_
#   inflating: maildir/allen-p/inbox/86_
#   inflating: maildir/allen-p/inbox/87_
#   inflating: maildir/allen-p/inbox/8_
#   inflating: maildir/allen-p/inbox/9_
#    creating: maildir/allen-p/notes_inbox/
#    creating: maildir/allen-p/sent/
#    creating: maildir/allen-p/sent_items/
#   inflating: maildir/allen-p/sent_items/100_
#   inflating: maildir/allen-p/sent_items/101_
#   inflating: maildir/allen-p/sent_items/102_
#   inflating: maildir/allen-p/sent_items/103_
#   inflating: maildir/allen-p/sent_items/104_
#   inflating: maildir/allen-p/sent_items/105_
#   inflating: maildir/allen-p/sent_items/106_
#   inflating: maildir/allen-p/sent_items/107_
#   inflating: maildir/allen-p/sent_items/108_
#   inflating: maildir/allen-p/sent_items/109_
#   inflating: maildir/allen-p/sent_items/10_
#   inflating: maildir/allen-p/sent_items/110_
#   inflating: maildir/allen-p/sent_items/111_
#   inflating: maildir/allen-p/sent_items/112_
#   inflating: maildir/allen-p/sent_items/113_
#   inflating: maildir/allen-p/sent_items/114_
#   inflating: maildir/allen-p/sent_items/115_
#   inflating: maildir/allen-p/sent_items/116_
#   inflating: maildir/allen-p/sent_items/117_
#   inflating: maildir/allen-p/sent_items/118_
#   inflating: maildir/allen-p/sent_items/119_
#   inflating: maildir/allen-p/sent_items/11_
#   inflating: maildir/allen-p/sent_items/120_
#   inflating: maildir/allen-p/sent_items/121_
#   inflating: maildir/allen-p/sent_items/122_
#   inflating: maildir/allen-p/sent_items/123_
#   inflating: maildir/allen-p/sent_items/124_
#   inflating: maildir/allen-p/sent_items/125_
#   inflating: maildir/allen-p/sent_items/126_
#   inflating: maildir/allen-p/sent_items/127_
#   inflating: maildir/allen-p/sent_items/128_
#   inflating: maildir/allen-p/sent_items/129_
#   inflating: maildir/allen-p/sent_items/12_
#   inflating: maildir/allen-p/sent_items/130_
#   inflating: maildir/allen-p/sent_items/131_
#   inflating: maildir/allen-p/sent_items/132_
#   inflating: maildir/allen-p/sent_items/133_
#   inflating: maildir/allen-p/sent_items/134_
#   inflating: maildir/allen-p/sent_items/135_
#   inflating: maildir/allen-p/sent_items/136_
#   inflating: maildir/allen-p/sent_items/137_
#   inflating: maildir/allen-p/sent_items/138_
#   inflating: maildir/allen-p/sent_items/139_
#   inflating: maildir/allen-p/sent_items/13_
#   inflating: maildir/allen-p/sent_items/140_
#   inflating: maildir/allen-p/sent_items/142_
#   inflating: maildir/allen-p/sent_items/143_
#   inflating: maildir/allen-p/sent_items/144_
#   inflating: maildir/allen-p/sent_items/145_
#   inflating: maildir/allen-p/sent_items/146_
#   inflating: maildir/allen-p/sent_items/147_
#   inflating: maildir/allen-p/sent_items/148_
#   inflating: maildir/allen-p/sent_items/149_
#   inflating: maildir/allen-p/sent_items/14_
#   inflating: maildir/allen-p/sent_items/150_
#   inflating: maildir/allen-p/sent_items/151_
#   inflating: maildir/allen-p/sent_items/152_
#   inflating: maildir/allen-p/sent_items/153_
#   inflating: maildir/allen-p/sent_items/154_
#   inflating: maildir/allen-p/sent_items/155_
#   inflating: maildir/allen-p/sent_items/156_
#   inflating: maildir/allen-p/sent_items/157_
#   inflating: maildir/allen-p/sent_items/158_
#   inflating: maildir/allen-p/sent_items/159_
#   inflating: maildir/allen-p/sent_items/15_
#   inflating: maildir/allen-p/sent_items/160_
#   inflating: maildir/allen-p/sent_items/161_
#   inflating: maildir/allen-p/sent_items/162_
#   inflating: maildir/allen-p/sent_items/163_
#   inflating: maildir/allen-p/sent_items/164_
#   inflating: maildir/allen-p/sent_items/165_
#   inflating: maildir/allen-p/sent_items/166_
#   inflating: maildir/allen-p/sent_items/167_
#   inflating: maildir/allen-p/sent_items/168_
#   inflating: maildir/allen-p/sent_items/169_
#   inflating: maildir/allen-p/sent_items/16_
#   inflating: maildir/allen-p/sent_items/170_
#   inflating: maildir/allen-p/sent_items/171_
#   inflating: maildir/allen-p/sent_items/172_
#   inflating: maildir/allen-p/sent_items/173_
#   inflating: maildir/allen-p/sent_items/174_
#   inflating: maildir/allen-p/sent_items/175_
#   inflating: maildir/allen-p/sent_items/176_
#   inflating: maildir/allen-p/sent_items/177_
#   inflating: maildir/allen-p/sent_items/178_
#   inflating: maildir/allen-p/sent_items/179_
#   inflating: maildir/allen-p/sent_items/17_
#   inflating: maildir/allen-p/sent_items/180_
#   inflating: maildir/allen-p/sent_items/181_
#   inflating: maildir/allen-p/sent_items/182_
#   inflating: maildir/allen-p/sent_items/183_
#   inflating: maildir/allen-p/sent_items/184_
#   inflating: maildir/allen-p/sent_items/185_
#   inflating: maildir/allen-p/sent_items/186_
#   inflating: maildir/allen-p/sent_items/187_
#   inflating: maildir/allen-p/sent_items/188_
#   inflating: maildir/allen-p/sent_items/189_
#   inflating: maildir/allen-p/sent_items/18_
#   inflating: maildir/allen-p/sent_items/190_
#   inflating: maildir/allen-p/sent_items/191_
#   inflating: maildir/allen-p/sent_items/192_
#   inflating: maildir/allen-p/sent_items/193_
#   inflating: maildir/allen-p/sent_items/194_
#   inflating: maildir/allen-p/sent_items/195_
#   inflating: maildir/allen-p/sent_items/196_
#   inflating: maildir/allen-p/sent_items/197_
#   inflating: maildir/allen-p/sent_items/198_
#   inflating: maildir/allen-p/sent_items/199_
#   inflating: maildir/allen-p/sent_items/19_
#   inflating: maildir/allen-p/sent_items/1_
#   inflating: maildir/allen-p/sent_items/200_
#   inflating: maildir/allen-p/sent_items/201_
#   inflating: maildir/allen-p/sent_items/202_
#   inflating: maildir/allen-p/sent_items/203_
#   inflating: maildir/allen-p/sent_items/204_
#   inflating: maildir/allen-p/sent_items/205_
#   inflating: maildir/allen-p/sent_items/206_
#   inflating: maildir/allen-p/sent_items/207_
#   inflating: maildir/allen-p/sent_items/208_
#   inflating: maildir/allen-p/sent_items/209_
#   inflating: maildir/allen-p/sent_items/20_
#   inflating: maildir/allen-p/sent_items/210_
#   inflating: maildir/allen-p/sent_items/211_
#   inflating: maildir/allen-p/sent_items/212_
#   inflating: maildir/allen-p/sent_items/213_
#   inflating: maildir/allen-p/sent_items/214_
#   inflating: maildir/allen-p/sent_items/215_
#   inflating: maildir/allen-p/sent_items/216_
#   inflating: maildir/allen-p/sent_items/217_
#   inflating: maildir/allen-p/sent_items/218_
#   inflating: maildir/allen-p/sent_items/219_
#   inflating: maildir/allen-p/sent_items/21_
#   inflating: maildir/allen-p/sent_items/220_
#   inflating: maildir/allen-p/sent_items/221_
#   inflating: maildir/allen-p/sent_items/222_
#   inflating: maildir/allen-p/sent_items/223_
#   inflating: maildir/allen-p/sent_items/224_
#   inflating: maildir/allen-p/sent_items/225_
#   inflating: maildir/allen-p/sent_items/226_
#   inflating: maildir/allen-p/sent_items/227_
#   inflating: maildir/allen-p/sent_items/228_
#   inflating: maildir/allen-p/sent_items/229_
#   inflating: maildir/allen-p/sent_items/22_
#   inflating: maildir/allen-p/sent_items/230_
#   inflating: maildir/allen-p/sent_items/231_
#   inflating: maildir/allen-p/sent_items/232_
#   inflating: maildir/allen-p/sent_items/233_
#   inflating: maildir/allen-p/sent_items/234_
#   inflating: maildir/allen-p/sent_items/235_
#   inflating: maildir/allen-p/sent_items/236_
#   inflating: maildir/allen-p/sent_items/237_
#   inflating: maildir/allen-p/sent_items/238_
#   inflating: maildir/allen-p/sent_items/239_
#   inflating: maildir/allen-p/sent_items/23_
#   inflating: maildir/allen-p/sent_items/240_
#   inflating: maildir/allen-p/sent_items/241_
#   inflating: maildir/allen-p/sent_items/242_
#   inflating: maildir/allen-p/sent_items/243_
#   inflating: maildir/allen-p/sent_items/244_
#   inflating: maildir/allen-p/sent_items/245_
#   inflating: maildir/allen-p/sent_items/246_
#   inflating: maildir/allen-p/sent_items/247_
#   inflating: maildir/allen-p/sent_items/248_
#   inflating: maildir/allen-p/sent_items/249_
#   inflating: maildir/allen-p/sent_items/24_
#   inflating: maildir/allen-p/sent_items/250_
#   inflating: maildir/allen-p/sent_items/251_
#   inflating: maildir/allen-p/sent_items/252_
#   inflating: maildir/allen-p/sent_items/253_
#   inflating: maildir/allen-p/sent_items/254_
#   inflating: maildir/allen-p/sent_items/255_
#   inflating: maildir/allen-p/sent_items/256_
#   inflating: maildir/allen-p/sent_items/257_
#   inflating: maildir/allen-p/sent_items/258_
#   inflating: maildir/allen-p/sent_items/259_
#   inflating: maildir/allen-p/sent_items/25_
#   inflating: maildir/allen-p/sent_items/260_
#   inflating: maildir/allen-p/sent_items/261_
#   inflating: maildir/allen-p/sent_items/262_
#   inflating: maildir/allen-p/sent_items/263_
#   inflating: maildir/allen-p/sent_items/264_
#   inflating: maildir/allen-p/sent_items/265_
#   inflating: maildir/allen-p/sent_items/266_
#   inflating: maildir/allen-p/sent_items/267_
#   inflating: maildir/allen-p/sent_items/268_
#   inflating: maildir/allen-p/sent_items/269_
#   inflating: maildir/allen-p/sent_items/26_
#   inflating: maildir/allen-p/sent_items/270_
#   inflating: maildir/allen-p/sent_items/271_
#   inflating: maildir/allen-p/sent_items/272_
#   inflating: maildir/allen-p/sent_items/273_
#   inflating: maildir/allen-p/sent_items/274_
#   inflating: maildir/allen-p/sent_items/275_
#   inflating: maildir/allen-p/sent_items/276_
#   inflating: maildir/allen-p/sent_items/277_
#   inflating: maildir/allen-p/sent_items/278_
#   inflating: maildir/allen-p/sent_items/279_
#   inflating: maildir/allen-p/sent_items/27_
#   inflating: maildir/allen-p/sent_items/280_
#   inflating: maildir/allen-p/sent_items/282_
#   inflating: maildir/allen-p/sent_items/283_
#   inflating: maildir/allen-p/sent_items/284_
#   inflating: maildir/allen-p/sent_items/285_
#   inflating: maildir/allen-p/sent_items/286_
#   inflating: maildir/allen-p/sent_items/287_
#   inflating: maildir/allen-p/sent_items/288_
#   inflating: maildir/allen-p/sent_items/289_
#   inflating: maildir/allen-p/sent_items/28_
#   inflating: maildir/allen-p/sent_items/290_
#   inflating: maildir/allen-p/sent_items/291_
#   inflating: maildir/allen-p/sent_items/292_
#   inflating: maildir/allen-p/sent_items/293_
#   inflating: maildir/allen-p/sent_items/294_
#   inflating: maildir/allen-p/sent_items/295_
#   inflating: maildir/allen-p/sent_items/296_
#   inflating: maildir/allen-p/sent_items/299_
#   inflating: maildir/allen-p/sent_items/29_
#   inflating: maildir/allen-p/sent_items/2_
#   inflating: maildir/allen-p/sent_items/300_
#   inflating: maildir/allen-p/sent_items/301_
#   inflating: maildir/allen-p/sent_items/302_
#   inflating: maildir/allen-p/sent_items/303_
#   inflating: maildir/allen-p/sent_items/304_
#   inflating: maildir/allen-p/sent_items/305_
#   inflating: maildir/allen-p/sent_items/306_
#   inflating: maildir/allen-p/sent_items/307_
#   inflating: maildir/allen-p/sent_items/308_
#   inflating: maildir/allen-p/sent_items/309_
#   inflating: maildir/allen-p/sent_items/30_
#   inflating: maildir/allen-p/sent_items/31_
#   inflating: maildir/allen-p/sent_items/32_
#   inflating: maildir/allen-p/sent_items/33_
#   inflating: maildir/allen-p/sent_items/34_
#   inflating: maildir/allen-p/sent_items/35_
#   inflating: maildir/allen-p/sent_items/368_
#   inflating: maildir/allen-p/sent_items/369_
#   inflating: maildir/allen-p/sent_items/36_
#   inflating: maildir/allen-p/sent_items/370_
#   inflating: maildir/allen-p/sent_items/371_
#   inflating: maildir/allen-p/sent_items/372_
#   inflating: maildir/allen-p/sent_items/373_
#   inflating: maildir/allen-p/sent_items/374_
#   inflating: maildir/allen-p/sent_items/375_
#   inflating: maildir/allen-p/sent_items/376_
#   inflating: maildir/allen-p/sent_items/377_
#   inflating: maildir/allen-p/sent_items/378_
#   inflating: maildir/allen-p/sent_items/379_
#   inflating: maildir/allen-p/sent_items/37_
#   inflating: maildir/allen-p/sent_items/380_
#   inflating: maildir/allen-p/sent_items/381_
#   inflating: maildir/allen-p/sent_items/382_
#   inflating: maildir/allen-p/sent_items/383_
#   inflating: maildir/allen-p/sent_items/384_
#   inflating: maildir/allen-p/sent_items/385_
#   inflating: maildir/allen-p/sent_items/386_
#   inflating: maildir/allen-p/sent_items/387_
#   inflating: maildir/allen-p/sent_items/388_
#   inflating: maildir/allen-p/sent_items/389_
#   inflating: maildir/allen-p/sent_items/38_
#   inflating: maildir/allen-p/sent_items/390_
#   inflating: maildir/allen-p/sent_items/391_
#   inflating: maildir/allen-p/sent_items/392_
#   inflating: maildir/allen-p/sent_items/393_
#   inflating: maildir/allen-p/sent_items/394_
#   inflating: maildir/allen-p/sent_items/395_
#   inflating: maildir/allen-p/sent_items/396_
#   inflating: maildir/allen-p/sent_items/397_
#   inflating: maildir/allen-p/sent_items/398_
#   inflating: maildir/allen-p/sent_items/399_
#   inflating: maildir/allen-p/sent_items/39_
#   inflating: maildir/allen-p/sent_items/3_
#   inflating: maildir/allen-p/sent_items/400_
#   inflating: maildir/allen-p/sent_items/401_
#   inflating: maildir/allen-p/sent_items/402_
#   inflating: maildir/allen-p/sent_items/405_
#   inflating: maildir/allen-p/sent_items/406_
#   inflating: maildir/allen-p/sent_items/407_
#   inflating: maildir/allen-p/sent_items/409_
#   inflating: maildir/allen-p/sent_items/40_
#   inflating: maildir/allen-p/sent_items/41_
#   inflating: maildir/allen-p/sent_items/42_
#   inflating: maildir/allen-p/sent_items/43_
#   inflating: maildir/allen-p/sent_items/446_
#   inflating: maildir/allen-p/sent_items/44_
#   inflating: maildir/allen-p/sent_items/45_
#   inflating: maildir/allen-p/sent_items/46_
#   inflating: maildir/allen-p/sent_items/47_
#   inflating: maildir/allen-p/sent_items/48_
#   inflating: maildir/allen-p/sent_items/49_
#   inflating: maildir/allen-p/sent_items/4_
#   inflating: maildir/allen-p/sent_items/50_
#   inflating: maildir/allen-p/sent_items/51_
#   inflating: maildir/allen-p/sent_items/52_
#   inflating: maildir/allen-p/sent_items/53_
#   inflating: maildir/allen-p/sent_items/54_
#   inflating: maildir/allen-p/sent_items/55_
#   inflating: maildir/allen-p/sent_items/56_
#   inflating: maildir/allen-p/sent_items/57_
#   inflating: maildir/allen-p/sent_items/58_
#   inflating: maildir/allen-p/sent_items/59_
#   inflating: maildir/allen-p/sent_items/5_
#   inflating: maildir/allen-p/sent_items/60_
#   inflating: maildir/allen-p/sent_items/61_
#   inflating: maildir/allen-p/sent_items/62_
#   inflating: maildir/allen-p/sent_items/63_
#   inflating: maildir/allen-p/sent_items/64_
#   inflating: maildir/allen-p/sent_items/65_
#   inflating: maildir/allen-p/sent_items/66_
#   inflating: maildir/allen-p/sent_items/67_
#   inflating: maildir/allen-p/sent_items/68_
#   inflating: maildir/allen-p/sent_items/69_
#   inflating: maildir/allen-p/sent_items/6_
#   inflating: maildir/allen-p/sent_items/70_
#   inflating: maildir/allen-p/sent_items/71_
#   inflating: maildir/allen-p/sent_items/72_
#   inflating: maildir/allen-p/sent_items/73_
#   inflating: maildir/allen-p/sent_items/74_
#   inflating: maildir/allen-p/sent_items/75_
#   inflating: maildir/allen-p/sent_items/76_
#   inflating: maildir/allen-p/sent_items/77_
#   inflating: maildir/allen-p/sent_items/78_
#   inflating: maildir/allen-p/sent_items/79_
#   inflating: maildir/allen-p/sent_items/7_
#   inflating: maildir/allen-p/sent_items/80_
#   inflating: maildir/allen-p/sent_items/81_
#   inflating: maildir/allen-p/sent_items/82_
#   inflating: maildir/allen-p/sent_items/83_
#   inflating: maildir/allen-p/sent_items/84_
#   inflating: maildir/allen-p/sent_items/85_
#   inflating: maildir/allen-p/sent_items/86_
#   inflating: maildir/allen-p/sent_items/87_
#   inflating: maildir/allen-p/sent_items/88_
#   inflating: maildir/allen-p/sent_items/89_
#   inflating: maildir/allen-p/sent_items/8_
#   inflating: maildir/allen-p/sent_items/90_
#   inflating: maildir/allen-p/sent_items/91_
#   inflating: maildir/allen-p/sent_items/92_
#   inflating: maildir/allen-p/sent_items/93_
#   inflating: maildir/allen-p/sent_items/94_
#   inflating: maildir/allen-p/sent_items/95_
#   inflating: maildir/allen-p/sent_items/96_
#   inflating: maildir/allen-p/sent_items/97_
#   inflating: maildir/allen-p/sent_items/98_
#   inflating: maildir/allen-p/sent_items/99_
#   inflating: maildir/allen-p/sent_items/9_
#    creating: maildir/allen-p/straw/
#    creating: maildir/allen-p/_sent_mail/
#    creating: maildir/arnold-j/
#    creating: maildir/arnold-j/2000_conference/
#    creating: maildir/arnold-j/active_international/
#    creating: maildir/arnold-j/all_documents/
#    creating: maildir/arnold-j/avaya/
#    creating: maildir/arnold-j/bmc/
#    creating: maildir/arnold-j/bridge/
#    creating: maildir/arnold-j/bristol_babcock/
#    creating: maildir/arnold-j/colleen_koenig/
#    creating: maildir/arnold-j/compaq/
#    creating: maildir/arnold-j/computer_associates/
#    creating: maildir/arnold-j/continental_airlines/
#    creating: maildir/arnold-j/cooper_cameron/
#    creating: maildir/arnold-j/corestaff/
#    creating: maildir/arnold-j/deleted_items/
#    creating: maildir/arnold-j/dell/
#    creating: maildir/arnold-j/discussion_threads/
#    creating: maildir/arnold-j/ebs/
#    creating: maildir/arnold-j/ees/
#    creating: maildir/arnold-j/enron_europe/
#    creating: maildir/arnold-j/etol/
#    creating: maildir/arnold-j/fedex/
#    creating: maildir/arnold-j/ge/
#    creating: maildir/arnold-j/hp/
#    creating: maildir/arnold-j/human_resources/
#    creating: maildir/arnold-j/inbox/
#   inflating: maildir/arnold-j/inbox/100_
#   inflating: maildir/arnold-j/inbox/10_
#   inflating: maildir/arnold-j/inbox/11_
#   inflating: maildir/arnold-j/inbox/12_
#   inflating: maildir/arnold-j/inbox/137_
#   inflating: maildir/arnold-j/inbox/138_
#   inflating: maildir/arnold-j/inbox/139_
#   inflating: maildir/arnold-j/inbox/13_
#   inflating: maildir/arnold-j/inbox/140_
#   inflating: maildir/arnold-j/inbox/141_
#   inflating: maildir/arnold-j/inbox/142_
#   inflating: maildir/arnold-j/inbox/143_
#   inflating: maildir/arnold-j/inbox/144_
#   inflating: maildir/arnold-j/inbox/145_
#   inflating: maildir/arnold-j/inbox/146_
#   inflating: maildir/arnold-j/inbox/147_
#   inflating: maildir/arnold-j/inbox/148_
#   inflating: maildir/arnold-j/inbox/149_
#   inflating: maildir/arnold-j/inbox/14_
#   inflating: maildir/arnold-j/inbox/150_
#   inflating: maildir/arnold-j/inbox/151_
#   inflating: maildir/arnold-j/inbox/152_
#   inflating: maildir/arnold-j/inbox/153_
#   inflating: maildir/arnold-j/inbox/154_
#   inflating: maildir/arnold-j/inbox/155_
#   inflating: maildir/arnold-j/inbox/156_
#   inflating: maildir/arnold-j/inbox/157_
#   inflating: maildir/arnold-j/inbox/158_
#   inflating: maildir/arnold-j/inbox/159_
#   inflating: maildir/arnold-j/inbox/15_
#   inflating: maildir/arnold-j/inbox/160_
#   inflating: maildir/arnold-j/inbox/161_
#   inflating: maildir/arnold-j/inbox/162_
#   inflating: maildir/arnold-j/inbox/163_
#   inflating: maildir/arnold-j/inbox/164_
#   inflating: maildir/arnold-j/inbox/165_
#   inflating: maildir/arnold-j/inbox/166_
#   inflating: maildir/arnold-j/inbox/167_
#   inflating: maildir/arnold-j/inbox/168_
#   inflating: maildir/arnold-j/inbox/169_
#   inflating: maildir/arnold-j/inbox/16_
#   inflating: maildir/arnold-j/inbox/170_
#   inflating: maildir/arnold-j/inbox/171_
#   inflating: maildir/arnold-j/inbox/172_
#   inflating: maildir/arnold-j/inbox/173_
#   inflating: maildir/arnold-j/inbox/174_
#   inflating: maildir/arnold-j/inbox/176_
#   inflating: maildir/arnold-j/inbox/177_
#   inflating: maildir/arnold-j/inbox/17_
#   inflating: maildir/arnold-j/inbox/18_
#   inflating: maildir/arnold-j/inbox/19_
#   inflating: maildir/arnold-j/inbox/1_
#   inflating: maildir/arnold-j/inbox/208_
#   inflating: maildir/arnold-j/inbox/209_
#   inflating: maildir/arnold-j/inbox/20_
#   inflating: maildir/arnold-j/inbox/21_
#   inflating: maildir/arnold-j/inbox/22_
#   inflating: maildir/arnold-j/inbox/23_
#   inflating: maildir/arnold-j/inbox/24_
#   inflating: maildir/arnold-j/inbox/25_
#   inflating: maildir/arnold-j/inbox/26_
#   inflating: maildir/arnold-j/inbox/27_
#   inflating: maildir/arnold-j/inbox/28_
#   inflating: maildir/arnold-j/inbox/29_
#   inflating: maildir/arnold-j/inbox/2_
#   inflating: maildir/arnold-j/inbox/30_
#   inflating: maildir/arnold-j/inbox/31_
#   inflating: maildir/arnold-j/inbox/32_
#   inflating: maildir/arnold-j/inbox/33_
#   inflating: maildir/arnold-j/inbox/34_
#   inflating: maildir/arnold-j/inbox/35_
#   inflating: maildir/arnold-j/inbox/36_
#   inflating: maildir/arnold-j/inbox/37_
#   inflating: maildir/arnold-j/inbox/38_
#   inflating: maildir/arnold-j/inbox/39_
#   inflating: maildir/arnold-j/inbox/3_
#   inflating: maildir/arnold-j/inbox/40_
#   inflating: maildir/arnold-j/inbox/41_
#   inflating: maildir/arnold-j/inbox/42_
#   inflating: maildir/arnold-j/inbox/43_
#   inflating: maildir/arnold-j/inbox/44_
#   inflating: maildir/arnold-j/inbox/45_
#   inflating: maildir/arnold-j/inbox/46_
#   inflating: maildir/arnold-j/inbox/47_
#   inflating: maildir/arnold-j/inbox/48_
#   inflating: maildir/arnold-j/inbox/49_
#   inflating: maildir/arnold-j/inbox/4_
#   inflating: maildir/arnold-j/inbox/50_
#   inflating: maildir/arnold-j/inbox/51_
#   inflating: maildir/arnold-j/inbox/52_
#   inflating: maildir/arnold-j/inbox/53_
#   inflating: maildir/arnold-j/inbox/54_
#   inflating: maildir/arnold-j/inbox/55_
#   inflating: maildir/arnold-j/inbox/56_
#   inflating: maildir/arnold-j/inbox/57_
#   inflating: maildir/arnold-j/inbox/58_
#   inflating: maildir/arnold-j/inbox/59_
#   inflating: maildir/arnold-j/inbox/5_
#   inflating: maildir/arnold-j/inbox/60_
#   inflating: maildir/arnold-j/inbox/61_
#   inflating: maildir/arnold-j/inbox/62_
#   inflating: maildir/arnold-j/inbox/63_
#   inflating: maildir/arnold-j/inbox/64_
#   inflating: maildir/arnold-j/inbox/65_
#   inflating: maildir/arnold-j/inbox/66_
#   inflating: maildir/arnold-j/inbox/67_
#   inflating: maildir/arnold-j/inbox/68_
#   inflating: maildir/arnold-j/inbox/69_
#   inflating: maildir/arnold-j/inbox/6_
#   inflating: maildir/arnold-j/inbox/70_
#   inflating: maildir/arnold-j/inbox/71_
#   inflating: maildir/arnold-j/inbox/72_
#   inflating: maildir/arnold-j/inbox/73_
#   inflating: maildir/arnold-j/inbox/74_
#   inflating: maildir/arnold-j/inbox/75_
#   inflating: maildir/arnold-j/inbox/76_
#   inflating: maildir/arnold-j/inbox/77_
#   inflating: maildir/arnold-j/inbox/78_
#   inflating: maildir/arnold-j/inbox/79_
#   inflating: maildir/arnold-j/inbox/7_
#   inflating: maildir/arnold-j/inbox/80_
#   inflating: maildir/arnold-j/inbox/81_
#   inflating: maildir/arnold-j/inbox/82_
#   inflating: maildir/arnold-j/inbox/83_
#   inflating: maildir/arnold-j/inbox/84_
#   inflating: maildir/arnold-j/inbox/85_
#   inflating: maildir/arnold-j/inbox/86_
#   inflating: maildir/arnold-j/inbox/87_
#   inflating: maildir/arnold-j/inbox/88_
#   inflating: maildir/arnold-j/inbox/89_
#   inflating: maildir/arnold-j/inbox/8_
#   inflating: maildir/arnold-j/inbox/90_
#   inflating: maildir/arnold-j/inbox/91_
#   inflating: maildir/arnold-j/inbox/92_
#   inflating: maildir/arnold-j/inbox/93_
#   inflating: maildir/arnold-j/inbox/94_
#   inflating: maildir/arnold-j/inbox/95_
#   inflating: maildir/arnold-j/inbox/96_
#   inflating: maildir/arnold-j/inbox/97_
#   inflating: maildir/arnold-j/inbox/98_
#   inflating: maildir/arnold-j/inbox/99_
#   inflating: maildir/arnold-j/inbox/9_
#    creating: maildir/arnold-j/kinko_s/
#    creating: maildir/arnold-j/nepco/
#    creating: maildir/arnold-j/nepco_europe/
#    creating: maildir/arnold-j/notes_inbox/
#    creating: maildir/arnold-j/oec/
#    creating: maildir/arnold-j/pcc_values/
#    creating: maildir/arnold-j/personal/
#    creating: maildir/arnold-j/purchasing/
#    creating: maildir/arnold-j/requisite/
#    creating: maildir/arnold-j/sap/
#    creating: maildir/arnold-j/sarah_joy_hunter/
#    creating: maildir/arnold-j/sent/
#    creating: maildir/arnold-j/sent_items/
#   inflating: maildir/arnold-j/sent_items/100_
#   inflating: maildir/arnold-j/sent_items/101_
#   inflating: maildir/arnold-j/sent_items/102_
#   inflating: maildir/arnold-j/sent_items/103_
#   inflating: maildir/arnold-j/sent_items/104_
#   inflating: maildir/arnold-j/sent_items/105_
#   inflating: maildir/arnold-j/sent_items/106_
#   inflating: maildir/arnold-j/sent_items/107_
#   inflating: maildir/arnold-j/sent_items/108_
#   inflating: maildir/arnold-j/sent_items/109_
#   inflating: maildir/arnold-j/sent_items/10_
#   inflating: maildir/arnold-j/sent_items/110_
#   inflating: maildir/arnold-j/sent_items/111_
#   inflating: maildir/arnold-j/sent_items/112_
#   inflating: maildir/arnold-j/sent_items/113_
#   inflating: maildir/arnold-j/sent_items/114_
#   inflating: maildir/arnold-j/sent_items/115_
#   inflating: maildir/arnold-j/sent_items/116_
#   inflating: maildir/arnold-j/sent_items/117_
#   inflating: maildir/arnold-j/sent_items/118_
#   inflating: maildir/arnold-j/sent_items/119_
#   inflating: maildir/arnold-j/sent_items/11_
#   inflating: maildir/arnold-j/sent_items/120_
#   inflating: maildir/arnold-j/sent_items/121_
#   inflating: maildir/arnold-j/sent_items/122_
#   inflating: maildir/arnold-j/sent_items/123_
#   inflating: maildir/arnold-j/sent_items/124_
#   inflating: maildir/arnold-j/sent_items/125_
#   inflating: maildir/arnold-j/sent_items/126_
#   inflating: maildir/arnold-j/sent_items/127_
#   inflating: maildir/arnold-j/sent_items/128_
#   inflating: maildir/arnold-j/sent_items/129_
#   inflating: maildir/arnold-j/sent_items/12_
#   inflating: maildir/arnold-j/sent_items/130_
#   inflating: maildir/arnold-j/sent_items/131_
#   inflating: maildir/arnold-j/sent_items/132_
#   inflating: maildir/arnold-j/sent_items/133_
#   inflating: maildir/arnold-j/sent_items/134_
#   inflating: maildir/arnold-j/sent_items/135_
#   inflating: maildir/arnold-j/sent_items/136_
#   inflating: maildir/arnold-j/sent_items/137_
#   inflating: maildir/arnold-j/sent_items/138_
#   inflating: maildir/arnold-j/sent_items/139_
#   inflating: maildir/arnold-j/sent_items/13_
#   inflating: maildir/arnold-j/sent_items/140_
#   inflating: maildir/arnold-j/sent_items/141_
#   inflating: maildir/arnold-j/sent_items/142_
#   inflating: maildir/arnold-j/sent_items/143_
#   inflating: maildir/arnold-j/sent_items/144_
#   inflating: maildir/arnold-j/sent_items/145_
#   inflating: maildir/arnold-j/sent_items/146_
#   inflating: maildir/arnold-j/sent_items/147_
#   inflating: maildir/arnold-j/sent_items/148_
#   inflating: maildir/arnold-j/sent_items/149_
#   inflating: maildir/arnold-j/sent_items/14_
#   inflating: maildir/arnold-j/sent_items/150_
#   inflating: maildir/arnold-j/sent_items/151_
#   inflating: maildir/arnold-j/sent_items/152_
#   inflating: maildir/arnold-j/sent_items/153_
#   inflating: maildir/arnold-j/sent_items/154_
#   inflating: maildir/arnold-j/sent_items/155_
#   inflating: maildir/arnold-j/sent_items/156_
#   inflating: maildir/arnold-j/sent_items/157_
#   inflating: maildir/arnold-j/sent_items/158_
#   inflating: maildir/arnold-j/sent_items/159_
#   inflating: maildir/arnold-j/sent_items/15_
#   inflating: maildir/arnold-j/sent_items/160_
#   inflating: maildir/arnold-j/sent_items/161_
#   inflating: maildir/arnold-j/sent_items/162_
#   inflating: maildir/arnold-j/sent_items/163_
#   inflating: maildir/arnold-j/sent_items/164_
#   inflating: maildir/arnold-j/sent_items/165_
#   inflating: maildir/arnold-j/sent_items/166_
#   inflating: maildir/arnold-j/sent_items/167_
#   inflating: maildir/arnold-j/sent_items/168_
#   inflating: maildir/arnold-j/sent_items/169_
#   inflating: maildir/arnold-j/sent_items/16_
#   inflating: maildir/arnold-j/sent_items/170_
#   inflating: maildir/arnold-j/sent_items/171_
#   inflating: maildir/arnold-j/sent_items/172_
#   inflating: maildir/arnold-j/sent_items/173_
#   inflating: maildir/arnold-j/sent_items/174_
#   inflating: maildir/arnold-j/sent_items/175_
#   inflating: maildir/arnold-j/sent_items/176_
#   inflating: maildir/arnold-j/sent_items/177_
#   inflating: maildir/arnold-j/sent_items/178_
#   inflating: maildir/arnold-j/sent_items/179_
#   inflating: maildir/arnold-j/sent_items/17_
#   inflating: maildir/arnold-j/sent_items/180_
#   inflating: maildir/arnold-j/sent_items/181_
#   inflating: maildir/arnold-j/sent_items/182_
#   inflating: maildir/arnold-j/sent_items/183_
#   inflating: maildir/arnold-j/sent_items/184_
#   inflating: maildir/arnold-j/sent_items/185_
#   inflating: maildir/arnold-j/sent_items/186_
#   inflating: maildir/arnold-j/sent_items/187_
#   inflating: maildir/arnold-j/sent_items/188_
#   inflating: maildir/arnold-j/sent_items/189_
#   inflating: maildir/arnold-j/sent_items/18_
#   inflating: maildir/arnold-j/sent_items/190_
#   inflating: maildir/arnold-j/sent_items/191_
#   inflating: maildir/arnold-j/sent_items/192_
#   inflating: maildir/arnold-j/sent_items/193_
#   inflating: maildir/arnold-j/sent_items/194_
#   inflating: maildir/arnold-j/sent_items/195_
#   inflating: maildir/arnold-j/sent_items/196_
#   inflating: maildir/arnold-j/sent_items/197_
#   inflating: maildir/arnold-j/sent_items/198_
#   inflating: maildir/arnold-j/sent_items/199_
#   inflating: maildir/arnold-j/sent_items/19_
#   inflating: maildir/arnold-j/sent_items/1_
#   inflating: maildir/arnold-j/sent_items/200_
#   inflating: maildir/arnold-j/sent_items/201_
#   inflating: maildir/arnold-j/sent_items/202_
#   inflating: maildir/arnold-j/sent_items/203_
#   inflating: maildir/arnold-j/sent_items/204_
#   inflating: maildir/arnold-j/sent_items/205_
#   inflating: maildir/arnold-j/sent_items/206_
#   inflating: maildir/arnold-j/sent_items/207_
#   inflating: maildir/arnold-j/sent_items/208_
#   inflating: maildir/arnold-j/sent_items/209_
#   inflating: maildir/arnold-j/sent_items/20_
#   inflating: maildir/arnold-j/sent_items/210_
#   inflating: maildir/arnold-j/sent_items/211_
#   inflating: maildir/arnold-j/sent_items/212_
#   inflating: maildir/arnold-j/sent_items/213_
#   inflating: maildir/arnold-j/sent_items/214_
#   inflating: maildir/arnold-j/sent_items/215_
#   inflating: maildir/arnold-j/sent_items/216_
#   inflating: maildir/arnold-j/sent_items/217_
#   inflating: maildir/arnold-j/sent_items/218_
#   inflating: maildir/arnold-j/sent_items/219_
#   inflating: maildir/arnold-j/sent_items/21_
#   inflating: maildir/arnold-j/sent_items/220_
#   inflating: maildir/arnold-j/sent_items/221_
#   inflating: maildir/arnold-j/sent_items/222_
#   inflating: maildir/arnold-j/sent_items/223_
#   inflating: maildir/arnold-j/sent_items/224_
#   inflating: maildir/arnold-j/sent_items/225_
#   inflating: maildir/arnold-j/sent_items/226_
#   inflating: maildir/arnold-j/sent_items/227_
#   inflating: maildir/arnold-j/sent_items/228_
#   inflating: maildir/arnold-j/sent_items/229_
#   inflating: maildir/arnold-j/sent_items/22_
#   inflating: maildir/arnold-j/sent_items/230_
#   inflating: maildir/arnold-j/sent_items/231_
#   inflating: maildir/arnold-j/sent_items/232_
#   inflating: maildir/arnold-j/sent_items/233_
#   inflating: maildir/arnold-j/sent_items/234_
#   inflating: maildir/arnold-j/sent_items/235_
#   inflating: maildir/arnold-j/sent_items/236_
#   inflating: maildir/arnold-j/sent_items/237_
#   inflating: maildir/arnold-j/sent_items/238_
#   inflating: maildir/arnold-j/sent_items/239_
#   inflating: maildir/arnold-j/sent_items/23_
#   inflating: maildir/arnold-j/sent_items/240_
#   inflating: maildir/arnold-j/sent_items/241_
#   inflating: maildir/arnold-j/sent_items/242_
#   inflating: maildir/arnold-j/sent_items/243_
#   inflating: maildir/arnold-j/sent_items/244_
#   inflating: maildir/arnold-j/sent_items/245_
#   inflating: maildir/arnold-j/sent_items/246_
#   inflating: maildir/arnold-j/sent_items/247_
#   inflating: maildir/arnold-j/sent_items/248_
#   inflating: maildir/arnold-j/sent_items/249_
#   inflating: maildir/arnold-j/sent_items/24_
#   inflating: maildir/arnold-j/sent_items/250_
#   inflating: maildir/arnold-j/sent_items/251_
#   inflating: maildir/arnold-j/sent_items/252_
#   inflating: maildir/arnold-j/sent_items/253_
#   inflating: maildir/arnold-j/sent_items/254_
#   inflating: maildir/arnold-j/sent_items/255_
#   inflating: maildir/arnold-j/sent_items/256_
#   inflating: maildir/arnold-j/sent_items/257_
#   inflating: maildir/arnold-j/sent_items/258_
#   inflating: maildir/arnold-j/sent_items/25_
#   inflating: maildir/arnold-j/sent_items/261_
#   inflating: maildir/arnold-j/sent_items/264_
#   inflating: maildir/arnold-j/sent_items/265_
#   inflating: maildir/arnold-j/sent_items/266_
#   inflating: maildir/arnold-j/sent_items/267_
#   inflating: maildir/arnold-j/sent_items/268_
#   inflating: maildir/arnold-j/sent_items/269_
#   inflating: maildir/arnold-j/sent_items/26_
#   inflating: maildir/arnold-j/sent_items/270_
#   inflating: maildir/arnold-j/sent_items/271_
#   inflating: maildir/arnold-j/sent_items/272_
#   inflating: maildir/arnold-j/sent_items/273_
#   inflating: maildir/arnold-j/sent_items/274_
#   inflating: maildir/arnold-j/sent_items/275_
#   inflating: maildir/arnold-j/sent_items/276_
#   inflating: maildir/arnold-j/sent_items/277_
#   inflating: maildir/arnold-j/sent_items/278_
#   inflating: maildir/arnold-j/sent_items/279_
#   inflating: maildir/arnold-j/sent_items/27_
#   inflating: maildir/arnold-j/sent_items/280_
#   inflating: maildir/arnold-j/sent_items/281_
#   inflating: maildir/arnold-j/sent_items/282_
#   inflating: maildir/arnold-j/sent_items/283_
#   inflating: maildir/arnold-j/sent_items/284_
#   inflating: maildir/arnold-j/sent_items/285_
#   inflating: maildir/arnold-j/sent_items/286_
#   inflating: maildir/arnold-j/sent_items/287_
#   inflating: maildir/arnold-j/sent_items/288_
#   inflating: maildir/arnold-j/sent_items/289_
#   inflating: maildir/arnold-j/sent_items/28_
#   inflating: maildir/arnold-j/sent_items/290_
#   inflating: maildir/arnold-j/sent_items/291_
#   inflating: maildir/arnold-j/sent_items/292_
#   inflating: maildir/arnold-j/sent_items/293_
#   inflating: maildir/arnold-j/sent_items/294_
#   inflating: maildir/arnold-j/sent_items/295_
#   inflating: maildir/arnold-j/sent_items/296_
#   inflating: maildir/arnold-j/sent_items/297_
#   inflating: maildir/arnold-j/sent_items/298_
#   inflating: maildir/arnold-j/sent_items/299_
#   inflating: maildir/arnold-j/sent_items/29_
#   inflating: maildir/arnold-j/sent_items/2_
#   inflating: maildir/arnold-j/sent_items/300_
#   inflating: maildir/arnold-j/sent_items/301_
#   inflating: maildir/arnold-j/sent_items/302_
#   inflating: maildir/arnold-j/sent_items/303_
#   inflating: maildir/arnold-j/sent_items/304_
#   inflating: maildir/arnold-j/sent_items/305_
#   inflating: maildir/arnold-j/sent_items/306_
#   inflating: maildir/arnold-j/sent_items/307_
#   inflating: maildir/arnold-j/sent_items/308_
#   inflating: maildir/arnold-j/sent_items/309_
#   inflating: maildir/arnold-j/sent_items/30_
#   inflating: maildir/arnold-j/sent_items/310_
#   inflating: maildir/arnold-j/sent_items/312_
#   inflating: maildir/arnold-j/sent_items/313_
#   inflating: maildir/arnold-j/sent_items/314_
#   inflating: maildir/arnold-j/sent_items/315_
#   inflating: maildir/arnold-j/sent_items/316_
#   inflating: maildir/arnold-j/sent_items/317_
#   inflating: maildir/arnold-j/sent_items/318_
#   inflating: maildir/arnold-j/sent_items/319_
#   inflating: maildir/arnold-j/sent_items/31_
#   inflating: maildir/arnold-j/sent_items/320_
#   inflating: maildir/arnold-j/sent_items/321_
#   inflating: maildir/arnold-j/sent_items/322_
#   inflating: maildir/arnold-j/sent_items/323_
#   inflating: maildir/arnold-j/sent_items/324_
#   inflating: maildir/arnold-j/sent_items/325_
#   inflating: maildir/arnold-j/sent_items/326_
#   inflating: maildir/arnold-j/sent_items/327_
#   inflating: maildir/arnold-j/sent_items/328_
#   inflating: maildir/arnold-j/sent_items/329_
#   inflating: maildir/arnold-j/sent_items/32_
#   inflating: maildir/arnold-j/sent_items/330_
#   inflating: maildir/arnold-j/sent_items/331_
#   inflating: maildir/arnold-j/sent_items/332_
#   inflating: maildir/arnold-j/sent_items/333_
#   inflating: maildir/arnold-j/sent_items/334_
#   inflating: maildir/arnold-j/sent_items/335_
#   inflating: maildir/arnold-j/sent_items/336_
#   inflating: maildir/arnold-j/sent_items/337_
#   inflating: maildir/arnold-j/sent_items/338_
#   inflating: maildir/arnold-j/sent_items/339_
#   inflating: maildir/arnold-j/sent_items/33_
#   inflating: maildir/arnold-j/sent_items/340_
#   inflating: maildir/arnold-j/sent_items/341_
#   inflating: maildir/arnold-j/sent_items/342_
#   inflating: maildir/arnold-j/sent_items/343_
#   inflating: maildir/arnold-j/sent_items/344_
#   inflating: maildir/arnold-j/sent_items/345_
#   inflating: maildir/arnold-j/sent_items/346_
#   inflating: maildir/arnold-j/sent_items/347_
#   inflating: maildir/arnold-j/sent_items/348_
#   inflating: maildir/arnold-j/sent_items/349_
#   inflating: maildir/arnold-j/sent_items/34_
#   inflating: maildir/arnold-j/sent_items/350_
#   inflating: maildir/arnold-j/sent_items/351_
#   inflating: maildir/arnold-j/sent_items/352_
#   inflating: maildir/arnold-j/sent_items/353_
#   inflating: maildir/arnold-j/sent_items/354_
#   inflating: maildir/arnold-j/sent_items/355_
#   inflating: maildir/arnold-j/sent_items/356_
#   inflating: maildir/arnold-j/sent_items/357_
#   inflating: maildir/arnold-j/sent_items/358_
#   inflating: maildir/arnold-j/sent_items/359_
#   inflating: maildir/arnold-j/sent_items/35_
#   inflating: maildir/arnold-j/sent_items/360_
#   inflating: maildir/arnold-j/sent_items/361_
#   inflating: maildir/arnold-j/sent_items/362_
#   inflating: maildir/arnold-j/sent_items/363_
#   inflating: maildir/arnold-j/sent_items/364_
#   inflating: maildir/arnold-j/sent_items/365_
#   inflating: maildir/arnold-j/sent_items/366_
#   inflating: maildir/arnold-j/sent_items/367_
#   inflating: maildir/arnold-j/sent_items/368_
#   inflating: maildir/arnold-j/sent_items/369_
#   inflating: maildir/arnold-j/sent_items/36_
#   inflating: maildir/arnold-j/sent_items/370_
#   inflating: maildir/arnold-j/sent_items/371_
#   inflating: maildir/arnold-j/sent_items/372_
#   inflating: maildir/arnold-j/sent_items/373_
#   inflating: maildir/arnold-j/sent_items/374_
#   inflating: maildir/arnold-j/sent_items/375_
#   inflating: maildir/arnold-j/sent_items/376_
#   inflating: maildir/arnold-j/sent_items/377_
#   inflating: maildir/arnold-j/sent_items/378_
#   inflating: maildir/arnold-j/sent_items/379_
#   inflating: maildir/arnold-j/sent_items/37_
#   inflating: maildir/arnold-j/sent_items/380_
#   inflating: maildir/arnold-j/sent_items/381_
#   inflating: maildir/arnold-j/sent_items/382_
#   inflating: maildir/arnold-j/sent_items/383_
#   inflating: maildir/arnold-j/sent_items/384_
#   inflating: maildir/arnold-j/sent_items/385_
#   inflating: maildir/arnold-j/sent_items/386_
#   inflating: maildir/arnold-j/sent_items/387_
#   inflating: maildir/arnold-j/sent_items/388_
#   inflating: maildir/arnold-j/sent_items/389_
#   inflating: maildir/arnold-j/sent_items/38_
#   inflating: maildir/arnold-j/sent_items/390_
#   inflating: maildir/arnold-j/sent_items/391_
#   inflating: maildir/arnold-j/sent_items/392_
#   inflating: maildir/arnold-j/sent_items/393_
#   inflating: maildir/arnold-j/sent_items/394_
#   inflating: maildir/arnold-j/sent_items/395_
#   inflating: maildir/arnold-j/sent_items/396_
#   inflating: maildir/arnold-j/sent_items/397_
#   inflating: maildir/arnold-j/sent_items/398_
#   inflating: maildir/arnold-j/sent_items/399_
#   inflating: maildir/arnold-j/sent_items/39_
#   inflating: maildir/arnold-j/sent_items/3_
#   inflating: maildir/arnold-j/sent_items/400_
#   inflating: maildir/arnold-j/sent_items/401_
#   inflating: maildir/arnold-j/sent_items/402_
#   inflating: maildir/arnold-j/sent_items/403_
#   inflating: maildir/arnold-j/sent_items/404_
#   inflating: maildir/arnold-j/sent_items/405_
#   inflating: maildir/arnold-j/sent_items/406_
#   inflating: maildir/arnold-j/sent_items/407_
#   inflating: maildir/arnold-j/sent_items/408_
#   inflating: maildir/arnold-j/sent_items/409_
#   inflating: maildir/arnold-j/sent_items/40_
#   inflating: maildir/arnold-j/sent_items/410_
#   inflating: maildir/arnold-j/sent_items/411_
#   inflating: maildir/arnold-j/sent_items/412_
#   inflating: maildir/arnold-j/sent_items/413_
#   inflating: maildir/arnold-j/sent_items/414_
#   inflating: maildir/arnold-j/sent_items/415_
#   inflating: maildir/arnold-j/sent_items/416_
#   inflating: maildir/arnold-j/sent_items/417_
#   inflating: maildir/arnold-j/sent_items/418_
#   inflating: maildir/arnold-j/sent_items/419_
#   inflating: maildir/arnold-j/sent_items/41_
#   inflating: maildir/arnold-j/sent_items/420_
#   inflating: maildir/arnold-j/sent_items/421_
#   inflating: maildir/arnold-j/sent_items/422_
#   inflating: maildir/arnold-j/sent_items/423_
#   inflating: maildir/arnold-j/sent_items/424_
#   inflating: maildir/arnold-j/sent_items/425_
#   inflating: maildir/arnold-j/sent_items/426_
#   inflating: maildir/arnold-j/sent_items/427_
#   inflating: maildir/arnold-j/sent_items/428_
#   inflating: maildir/arnold-j/sent_items/429_
#   inflating: maildir/arnold-j/sent_items/42_
#   inflating: maildir/arnold-j/sent_items/431_
#   inflating: maildir/arnold-j/sent_items/432_
#   inflating: maildir/arnold-j/sent_items/433_
#   inflating: maildir/arnold-j/sent_items/434_
#   inflating: maildir/arnold-j/sent_items/435_
#   inflating: maildir/arnold-j/sent_items/436_
#   inflating: maildir/arnold-j/sent_items/437_
#   inflating: maildir/arnold-j/sent_items/438_
#   inflating: maildir/arnold-j/sent_items/439_
#   inflating: maildir/arnold-j/sent_items/43_
#   inflating: maildir/arnold-j/sent_items/440_
#   inflating: maildir/arnold-j/sent_items/441_
#   inflating: maildir/arnold-j/sent_items/442_
#   inflating: maildir/arnold-j/sent_items/443_
#   inflating: maildir/arnold-j/sent_items/444_
#   inflating: maildir/arnold-j/sent_items/445_
#   inflating: maildir/arnold-j/sent_items/446_
#   inflating: maildir/arnold-j/sent_items/447_
#   inflating: maildir/arnold-j/sent_items/448_
#   inflating: maildir/arnold-j/sent_items/449_
#   inflating: maildir/arnold-j/sent_items/44_
#   inflating: maildir/arnold-j/sent_items/450_
#   inflating: maildir/arnold-j/sent_items/451_
#   inflating: maildir/arnold-j/sent_items/452_
#   inflating: maildir/arnold-j/sent_items/453_
#   inflating: maildir/arnold-j/sent_items/454_
#   inflating: maildir/arnold-j/sent_items/455_
#   inflating: maildir/arnold-j/sent_items/456_
#   inflating: maildir/arnold-j/sent_items/457_
#   inflating: maildir/arnold-j/sent_items/458_
#   inflating: maildir/arnold-j/sent_items/459_
#   inflating: maildir/arnold-j/sent_items/45_
#   inflating: maildir/arnold-j/sent_items/460_
#   inflating: maildir/arnold-j/sent_items/461_
#   inflating: maildir/arnold-j/sent_items/462_
#   inflating: maildir/arnold-j/sent_items/463_
#   inflating: maildir/arnold-j/sent_items/464_
#   inflating: maildir/arnold-j/sent_items/465_
#   inflating: maildir/arnold-j/sent_items/466_
#   inflating: maildir/arnold-j/sent_items/467_
#   inflating: maildir/arnold-j/sent_items/468_
#   inflating: maildir/arnold-j/sent_items/469_
#   inflating: maildir/arnold-j/sent_items/46_
#   inflating: maildir/arnold-j/sent_items/470_
#   inflating: maildir/arnold-j/sent_items/471_
#   inflating: maildir/arnold-j/sent_items/472_
#   inflating: maildir/arnold-j/sent_items/473_
#   inflating: maildir/arnold-j/sent_items/474_
#   inflating: maildir/arnold-j/sent_items/475_
#   inflating: maildir/arnold-j/sent_items/476_
#   inflating: maildir/arnold-j/sent_items/477_
#   inflating: maildir/arnold-j/sent_items/478_
#   inflating: maildir/arnold-j/sent_items/479_
#   inflating: maildir/arnold-j/sent_items/47_
#   inflating: maildir/arnold-j/sent_items/480_
#   inflating: maildir/arnold-j/sent_items/481_
#   inflating: maildir/arnold-j/sent_items/482_
#   inflating: maildir/arnold-j/sent_items/483_
#   inflating: maildir/arnold-j/sent_items/484_
#   inflating: maildir/arnold-j/sent_items/485_
#   inflating: maildir/arnold-j/sent_items/486_
#   inflating: maildir/arnold-j/sent_items/487_
#   inflating: maildir/arnold-j/sent_items/488_
#   inflating: maildir/arnold-j/sent_items/489_
#   inflating: maildir/arnold-j/sent_items/48_
#   inflating: maildir/arnold-j/sent_items/490_
#   inflating: maildir/arnold-j/sent_items/491_
#   inflating: maildir/arnold-j/sent_items/492_
#   inflating: maildir/arnold-j/sent_items/493_
#   inflating: maildir/arnold-j/sent_items/494_
#   inflating: maildir/arnold-j/sent_items/495_
#   inflating: maildir/arnold-j/sent_items/496_
#   inflating: maildir/arnold-j/sent_items/497_
#   inflating: maildir/arnold-j/sent_items/498_
#   inflating: maildir/arnold-j/sent_items/499_
#   inflating: maildir/arnold-j/sent_items/49_
#   inflating: maildir/arnold-j/sent_items/4_
# ...
#   inflating: maildir/presto-k/sent_items/996_
#   inflating: maildir/presto-k/sent_items/997_
#   inflating: maildir/presto-k/sent_items/998_
#   inflating: maildir/presto-k/sent_items/999_
#   inflating: maildir/presto-k/sent_items/99_
#   inflating: maildir/presto-k/sent_items/9_
#    creating: maildir/quenet-j/
#    creating: maildir/quenet-j/all_documents/
#    creating: maildir/quenet-j/deleted_items/
#    creating: maildir/quenet-j/discussion_threads/
#    creating: maildir/quenet-j/inbox/
#   inflating: maildir/quenet-j/inbox/10_
#   inflating: maildir/quenet-j/inbox/11_
#   inflating: maildir/quenet-j/inbox/12_
#   inflating: maildir/quenet-j/inbox/14_
#   inflating: maildir/quenet-j/inbox/15_
#   inflating: maildir/quenet-j/inbox/1_
#   inflating: maildir/quenet-j/inbox/2_
#   inflating: maildir/quenet-j/inbox/3_
#   inflating: maildir/quenet-j/inbox/4_
#   inflating: maildir/quenet-j/inbox/5_
#   inflating: maildir/quenet-j/inbox/6_
#   inflating: maildir/quenet-j/inbox/8_
#   inflating: maildir/quenet-j/inbox/9_
#    creating: maildir/quenet-j/notes_inbox/
#    creating: maildir/quenet-j/sent/
#    creating: maildir/quenet-j/sent_items/
#   inflating: maildir/quenet-j/sent_items/1_
#   inflating: maildir/quenet-j/sent_items/2_
#   inflating: maildir/quenet-j/sent_items/3_
#   inflating: maildir/quenet-j/sent_items/4_
#   inflating: maildir/quenet-j/sent_items/5_
#   inflating: maildir/quenet-j/sent_items/6_
#    creating: maildir/quenet-j/_sent_mail/
#    creating: maildir/quigley-d/
#    creating: maildir/quigley-d/bmr/
#    creating: maildir/quigley-d/calendar/
#    creating: maildir/quigley-d/carr/
#    creating: maildir/quigley-d/deleted_items/
#    creating: maildir/quigley-d/fin_desk/
#    creating: maildir/quigley-d/ina/
#    creating: maildir/quigley-d/inbox/
#   inflating: maildir/quigley-d/inbox/10_
#   inflating: maildir/quigley-d/inbox/11_
#   inflating: maildir/quigley-d/inbox/120_
#   inflating: maildir/quigley-d/inbox/121_
#   inflating: maildir/quigley-d/inbox/122_
#   inflating: maildir/quigley-d/inbox/123_
#   inflating: maildir/quigley-d/inbox/124_
#   inflating: maildir/quigley-d/inbox/126_
#   inflating: maildir/quigley-d/inbox/127_
#   inflating: maildir/quigley-d/inbox/128_
#   inflating: maildir/quigley-d/inbox/129_
#   inflating: maildir/quigley-d/inbox/12_
#   inflating: maildir/quigley-d/inbox/130_
#   inflating: maildir/quigley-d/inbox/131_
#   inflating: maildir/quigley-d/inbox/13_
#   inflating: maildir/quigley-d/inbox/141_
#   inflating: maildir/quigley-d/inbox/142_
#   inflating: maildir/quigley-d/inbox/14_
#   inflating: maildir/quigley-d/inbox/15_
#   inflating: maildir/quigley-d/inbox/16_
#   inflating: maildir/quigley-d/inbox/17_
#   inflating: maildir/quigley-d/inbox/18_
#   inflating: maildir/quigley-d/inbox/19_
#   inflating: maildir/quigley-d/inbox/1_
#   inflating: maildir/quigley-d/inbox/20_
#   inflating: maildir/quigley-d/inbox/21_
#   inflating: maildir/quigley-d/inbox/22_
#   inflating: maildir/quigley-d/inbox/23_
#   inflating: maildir/quigley-d/inbox/24_
#   inflating: maildir/quigley-d/inbox/25_
#   inflating: maildir/quigley-d/inbox/26_
#   inflating: maildir/quigley-d/inbox/27_
#   inflating: maildir/quigley-d/inbox/28_
#   inflating: maildir/quigley-d/inbox/29_
#   inflating: maildir/quigley-d/inbox/2_
#   inflating: maildir/quigley-d/inbox/30_
#   inflating: maildir/quigley-d/inbox/31_
#   inflating: maildir/quigley-d/inbox/32_
#   inflating: maildir/quigley-d/inbox/33_
#   inflating: maildir/quigley-d/inbox/34_
#   inflating: maildir/quigley-d/inbox/35_
#   inflating: maildir/quigley-d/inbox/36_
#   inflating: maildir/quigley-d/inbox/37_
#   inflating: maildir/quigley-d/inbox/38_
#   inflating: maildir/quigley-d/inbox/39_
#   inflating: maildir/quigley-d/inbox/3_
#   inflating: maildir/quigley-d/inbox/40_
#   inflating: maildir/quigley-d/inbox/41_
#   inflating: maildir/quigley-d/inbox/42_
#   inflating: maildir/quigley-d/inbox/43_
#   inflating: maildir/quigley-d/inbox/44_
#   inflating: maildir/quigley-d/inbox/45_
#   inflating: maildir/quigley-d/inbox/46_
#   inflating: maildir/quigley-d/inbox/47_
#   inflating: maildir/quigley-d/inbox/48_
#   inflating: maildir/quigley-d/inbox/49_
#   inflating: maildir/quigley-d/inbox/4_
#   inflating: maildir/quigley-d/inbox/50_
#   inflating: maildir/quigley-d/inbox/51_
#   inflating: maildir/quigley-d/inbox/52_
#   inflating: maildir/quigley-d/inbox/53_
#   inflating: maildir/quigley-d/inbox/54_
#   inflating: maildir/quigley-d/inbox/55_
#   inflating: maildir/quigley-d/inbox/56_
#   inflating: maildir/quigley-d/inbox/57_
#   inflating: maildir/quigley-d/inbox/59_
#   inflating: maildir/quigley-d/inbox/5_
#   inflating: maildir/quigley-d/inbox/60_
#   inflating: maildir/quigley-d/inbox/61_
#   inflating: maildir/quigley-d/inbox/62_
#   inflating: maildir/quigley-d/inbox/63_
#   inflating: maildir/quigley-d/inbox/64_
#   inflating: maildir/quigley-d/inbox/65_
#   inflating: maildir/quigley-d/inbox/66_
#   inflating: maildir/quigley-d/inbox/67_
#   inflating: maildir/quigley-d/inbox/68_
#   inflating: maildir/quigley-d/inbox/69_
#   inflating: maildir/quigley-d/inbox/6_
#   inflating: maildir/quigley-d/inbox/70_
#   inflating: maildir/quigley-d/inbox/71_
#   inflating: maildir/quigley-d/inbox/72_
#   inflating: maildir/quigley-d/inbox/73_
#   inflating: maildir/quigley-d/inbox/74_
#   inflating: maildir/quigley-d/inbox/75_
#   inflating: maildir/quigley-d/inbox/76_
#   inflating: maildir/quigley-d/inbox/77_
#   inflating: maildir/quigley-d/inbox/78_
#   inflating: maildir/quigley-d/inbox/79_
#   inflating: maildir/quigley-d/inbox/7_
#   inflating: maildir/quigley-d/inbox/80_
#   inflating: maildir/quigley-d/inbox/81_
#   inflating: maildir/quigley-d/inbox/82_
#   inflating: maildir/quigley-d/inbox/83_
#   inflating: maildir/quigley-d/inbox/84_
#   inflating: maildir/quigley-d/inbox/85_
#   inflating: maildir/quigley-d/inbox/86_
#   inflating: maildir/quigley-d/inbox/87_
#   inflating: maildir/quigley-d/inbox/88_
#   inflating: maildir/quigley-d/inbox/8_
#   inflating: maildir/quigley-d/inbox/90_
#   inflating: maildir/quigley-d/inbox/91_
#   inflating: maildir/quigley-d/inbox/9_
#    creating: maildir/quigley-d/mid_market/
#    creating: maildir/quigley-d/myfriends/
#    creating: maildir/quigley-d/prc/
#    creating: maildir/quigley-d/private_folders/
#    creating: maildir/quigley-d/sent_items/
#   inflating: maildir/quigley-d/sent_items/100_
#   inflating: maildir/quigley-d/sent_items/101_
#   inflating: maildir/quigley-d/sent_items/102_
#   inflating: maildir/quigley-d/sent_items/103_
#   inflating: maildir/quigley-d/sent_items/104_
#   inflating: maildir/quigley-d/sent_items/105_
#   inflating: maildir/quigley-d/sent_items/106_
#   inflating: maildir/quigley-d/sent_items/107_
#   inflating: maildir/quigley-d/sent_items/108_
#   inflating: maildir/quigley-d/sent_items/109_
#   inflating: maildir/quigley-d/sent_items/10_
#   inflating: maildir/quigley-d/sent_items/110_
#   inflating: maildir/quigley-d/sent_items/111_
#   inflating: maildir/quigley-d/sent_items/112_
#   inflating: maildir/quigley-d/sent_items/113_
#   inflating: maildir/quigley-d/sent_items/114_
#   inflating: maildir/quigley-d/sent_items/115_
#   inflating: maildir/quigley-d/sent_items/116_
#   inflating: maildir/quigley-d/sent_items/117_
#   inflating: maildir/quigley-d/sent_items/118_
#   inflating: maildir/quigley-d/sent_items/119_
#   inflating: maildir/quigley-d/sent_items/11_
#   inflating: maildir/quigley-d/sent_items/120_
#   inflating: maildir/quigley-d/sent_items/121_
#   inflating: maildir/quigley-d/sent_items/122_
#   inflating: maildir/quigley-d/sent_items/123_
#   inflating: maildir/quigley-d/sent_items/125_
#   inflating: maildir/quigley-d/sent_items/126_
#   inflating: maildir/quigley-d/sent_items/128_
#   inflating: maildir/quigley-d/sent_items/129_
#   inflating: maildir/quigley-d/sent_items/12_
#   inflating: maildir/quigley-d/sent_items/130_
#   inflating: maildir/quigley-d/sent_items/131_
#   inflating: maildir/quigley-d/sent_items/132_
#   inflating: maildir/quigley-d/sent_items/133_
#   inflating: maildir/quigley-d/sent_items/134_
#   inflating: maildir/quigley-d/sent_items/135_
#   inflating: maildir/quigley-d/sent_items/136_
#   inflating: maildir/quigley-d/sent_items/137_
#   inflating: maildir/quigley-d/sent_items/138_
#   inflating: maildir/quigley-d/sent_items/139_
#   inflating: maildir/quigley-d/sent_items/13_
#   inflating: maildir/quigley-d/sent_items/140_
#   inflating: maildir/quigley-d/sent_items/141_
#   inflating: maildir/quigley-d/sent_items/142_
#   inflating: maildir/quigley-d/sent_items/143_
#   inflating: maildir/quigley-d/sent_items/144_
#   inflating: maildir/quigley-d/sent_items/145_
#   inflating: maildir/quigley-d/sent_items/146_
#   inflating: maildir/quigley-d/sent_items/147_
#   inflating: maildir/quigley-d/sent_items/148_
#   inflating: maildir/quigley-d/sent_items/149_
#   inflating: maildir/quigley-d/sent_items/14_
#   inflating: maildir/quigley-d/sent_items/150_
#   inflating: maildir/quigley-d/sent_items/151_
#   inflating: maildir/quigley-d/sent_items/152_
#   inflating: maildir/quigley-d/sent_items/153_
#   inflating: maildir/quigley-d/sent_items/154_
#   inflating: maildir/quigley-d/sent_items/155_
#   inflating: maildir/quigley-d/sent_items/156_
#   inflating: maildir/quigley-d/sent_items/157_
#   inflating: maildir/quigley-d/sent_items/158_
#   inflating: maildir/quigley-d/sent_items/159_
#   inflating: maildir/quigley-d/sent_items/15_
#   inflating: maildir/quigley-d/sent_items/160_
#   inflating: maildir/quigley-d/sent_items/161_
#   inflating: maildir/quigley-d/sent_items/162_
#   inflating: maildir/quigley-d/sent_items/163_
#   inflating: maildir/quigley-d/sent_items/164_
#   inflating: maildir/quigley-d/sent_items/165_
#   inflating: maildir/quigley-d/sent_items/166_
#   inflating: maildir/quigley-d/sent_items/167_
#   inflating: maildir/quigley-d/sent_items/168_
#   inflating: maildir/quigley-d/sent_items/169_
#   inflating: maildir/quigley-d/sent_items/16_
#   inflating: maildir/quigley-d/sent_items/170_
#   inflating: maildir/quigley-d/sent_items/171_
#   inflating: maildir/quigley-d/sent_items/172_
#   inflating: maildir/quigley-d/sent_items/173_
#   inflating: maildir/quigley-d/sent_items/174_
#   inflating: maildir/quigley-d/sent_items/175_
#   inflating: maildir/quigley-d/sent_items/176_
#   inflating: maildir/quigley-d/sent_items/177_
#   inflating: maildir/quigley-d/sent_items/178_
#   inflating: maildir/quigley-d/sent_items/179_
#   inflating: maildir/quigley-d/sent_items/17_
#   inflating: maildir/quigley-d/sent_items/180_
#   inflating: maildir/quigley-d/sent_items/181_
#   inflating: maildir/quigley-d/sent_items/182_
#   inflating: maildir/quigley-d/sent_items/183_
#   inflating: maildir/quigley-d/sent_items/184_
#   inflating: maildir/quigley-d/sent_items/185_
#   inflating: maildir/quigley-d/sent_items/186_
#   inflating: maildir/quigley-d/sent_items/187_
#   inflating: maildir/quigley-d/sent_items/188_
#   inflating: maildir/quigley-d/sent_items/189_
#   inflating: maildir/quigley-d/sent_items/18_
#   inflating: maildir/quigley-d/sent_items/190_
#   inflating: maildir/quigley-d/sent_items/191_
#   inflating: maildir/quigley-d/sent_items/192_
#   inflating: maildir/quigley-d/sent_items/193_
#   inflating: maildir/quigley-d/sent_items/194_
#   inflating: maildir/quigley-d/sent_items/195_
#   inflating: maildir/quigley-d/sent_items/197_
#   inflating: maildir/quigley-d/sent_items/198_
#   inflating: maildir/quigley-d/sent_items/199_
#   inflating: maildir/quigley-d/sent_items/19_
#   inflating: maildir/quigley-d/sent_items/1_
#   inflating: maildir/quigley-d/sent_items/200_
#   inflating: maildir/quigley-d/sent_items/201_
#   inflating: maildir/quigley-d/sent_items/202_
#   inflating: maildir/quigley-d/sent_items/203_
#   inflating: maildir/quigley-d/sent_items/204_
#   inflating: maildir/quigley-d/sent_items/205_
#   inflating: maildir/quigley-d/sent_items/206_
#   inflating: maildir/quigley-d/sent_items/207_
#   inflating: maildir/quigley-d/sent_items/208_
#   inflating: maildir/quigley-d/sent_items/209_
#   inflating: maildir/quigley-d/sent_items/20_
#   inflating: maildir/quigley-d/sent_items/210_
#   inflating: maildir/quigley-d/sent_items/211_
#   inflating: maildir/quigley-d/sent_items/213_
#   inflating: maildir/quigley-d/sent_items/214_
#   inflating: maildir/quigley-d/sent_items/215_
#   inflating: maildir/quigley-d/sent_items/216_
#   inflating: maildir/quigley-d/sent_items/217_
#   inflating: maildir/quigley-d/sent_items/218_
#   inflating: maildir/quigley-d/sent_items/219_
#   inflating: maildir/quigley-d/sent_items/21_
#   inflating: maildir/quigley-d/sent_items/220_
#   inflating: maildir/quigley-d/sent_items/221_
#   inflating: maildir/quigley-d/sent_items/222_
#   inflating: maildir/quigley-d/sent_items/223_
#   inflating: maildir/quigley-d/sent_items/224_
#   inflating: maildir/quigley-d/sent_items/225_
#   inflating: maildir/quigley-d/sent_items/226_
#   inflating: maildir/quigley-d/sent_items/227_
#   inflating: maildir/quigley-d/sent_items/228_
#   inflating: maildir/quigley-d/sent_items/229_
#   inflating: maildir/quigley-d/sent_items/22_
#   inflating: maildir/quigley-d/sent_items/230_
#   inflating: maildir/quigley-d/sent_items/231_
#   inflating: maildir/quigley-d/sent_items/232_
#   inflating: maildir/quigley-d/sent_items/233_
#   inflating: maildir/quigley-d/sent_items/234_
#   inflating: maildir/quigley-d/sent_items/235_
#   inflating: maildir/quigley-d/sent_items/236_
#   inflating: maildir/quigley-d/sent_items/237_
#   inflating: maildir/quigley-d/sent_items/238_
#   inflating: maildir/quigley-d/sent_items/239_
#   inflating: maildir/quigley-d/sent_items/23_
#   inflating: maildir/quigley-d/sent_items/240_
#   inflating: maildir/quigley-d/sent_items/241_
#   inflating: maildir/quigley-d/sent_items/242_
#   inflating: maildir/quigley-d/sent_items/243_
#   inflating: maildir/quigley-d/sent_items/244_
#   inflating: maildir/quigley-d/sent_items/245_
#   inflating: maildir/quigley-d/sent_items/246_
#   inflating: maildir/quigley-d/sent_items/247_
#   inflating: maildir/quigley-d/sent_items/248_
#   inflating: maildir/quigley-d/sent_items/249_
#   inflating: maildir/quigley-d/sent_items/24_
#   inflating: maildir/quigley-d/sent_items/250_
#   inflating: maildir/quigley-d/sent_items/251_
#   inflating: maildir/quigley-d/sent_items/252_
#   inflating: maildir/quigley-d/sent_items/253_
#   inflating: maildir/quigley-d/sent_items/254_
#   inflating: maildir/quigley-d/sent_items/255_
#   inflating: maildir/quigley-d/sent_items/256_
#   inflating: maildir/quigley-d/sent_items/257_
#   inflating: maildir/quigley-d/sent_items/258_
#   inflating: maildir/quigley-d/sent_items/25_
#   inflating: maildir/quigley-d/sent_items/260_
#   inflating: maildir/quigley-d/sent_items/261_
#   inflating: maildir/quigley-d/sent_items/262_
#   inflating: maildir/quigley-d/sent_items/263_
#   inflating: maildir/quigley-d/sent_items/264_
#   inflating: maildir/quigley-d/sent_items/265_
#   inflating: maildir/quigley-d/sent_items/266_
#   inflating: maildir/quigley-d/sent_items/267_
#   inflating: maildir/quigley-d/sent_items/268_
#   inflating: maildir/quigley-d/sent_items/269_
#   inflating: maildir/quigley-d/sent_items/26_
#   inflating: maildir/quigley-d/sent_items/270_
#   inflating: maildir/quigley-d/sent_items/271_
#   inflating: maildir/quigley-d/sent_items/272_
#   inflating: maildir/quigley-d/sent_items/273_
#   inflating: maildir/quigley-d/sent_items/274_
#   inflating: maildir/quigley-d/sent_items/275_
#   inflating: maildir/quigley-d/sent_items/276_
#   inflating: maildir/quigley-d/sent_items/277_
#   inflating: maildir/quigley-d/sent_items/278_
#   inflating: maildir/quigley-d/sent_items/279_
#   inflating: maildir/quigley-d/sent_items/27_
#   inflating: maildir/quigley-d/sent_items/280_
#   inflating: maildir/quigley-d/sent_items/281_

# %% [markdown]
# The bullets below represent the file structure of interest from the Enron dataset. To confirm that you have unzipped and placed the data in the correct location, click on the links of files, e.g. `1_`, `2_`, etc., which will open the text files for you to explore. Notice that these are all raw text files.

# %% [markdown]
# * [maildir](./maildir)
#  * [allen-p](./maildir/allen-p)
#    * [inbox](./maildir/allen-p/inbox)
#        * [1_](./maildir/allen-p/inbox/1_)
#        * [2_](./maildir/allen-p/inbox/2_)
#        * [3_](./maildir/allen-p/inbox/3_)
#        ...
#    * [sent_items](./maildir/allen-p/sent_items)
#        * [1_](./maildir/allen-p/sent_items/1_)
#        * [2_](./maildir/allen-p/sent_items/2_)
#        * [3_](./maildir/allen-p/sent_items/3_)
#        * etc...
#    * etc...
#  * [arnold-j](./maildir/arnold-j)
#    * [inbox](./maildir/arnold-j/inbox)
#        * [1_](./maildir/arnold-j/inbox/1_)
#        * [2_](./maildir/arnold-j/inbox/2_)
#        * [3_](./maildir/arnold-j/inbox/3_)
#        * etc ...
#    * [sent_items](./maildir/arnold-j/sent_items)
#        * [1_](./maildir/arnold-j/sent_items/1_)
#        * [2_](./maildir/arnold-j/sent_items/2_)
#        * [3_](./maildir/arnold-j/sent_items/3_)
#        * etc...
#    * etc...
#  * [arora-h](./maildir/arora-h)
#    * [inbox](./maildir/arora-h/inbox)
#        * [1_](./maildir/arora-h/inbox/1_)
#        * [2_](./maildir/arora-h/inbox/2_)
#        * [3_](./maildir/arora-h/inbox/3_)
#        * etc...
#    * [sent_items](./maildir/arora-h/sent_items)
#        * [1_](./maildir/arora-h/sent_items/1_)
#        * [2_](./maildir/arora-h/sent_items/2_)
#        * [3_](./maildir/arora-h/sent_items/3_)
#        * etc...
#    * etc...
#  * etc... etc...

# %% [markdown]
# ---------------------------

# %% [markdown]
# ### Task #1: Collect all of the file paths of emails in the maildir (6 points)
#
# The output object will be called `list_emails` should contain 79,429 items and look similar to the following:
# ```
# ['maildir\\allen-p\\inbox\\10_',
#  'maildir\\allen-p\\inbox\\11_',
#  'maildir\\allen-p\\inbox\\12_',
#  'maildir\\allen-p\\inbox\\13_',
#  'maildir\\allen-p\\inbox\\14_',
#  'maildir\\allen-p\\inbox\\15_',
#  'maildir\\allen-p\\inbox\\16_',
#  'maildir\\allen-p\\inbox\\17_',
#  'maildir\\allen-p\\inbox\\18_',
#  'maildir\\allen-p\\inbox\\19_',
#  .....
#  ]
# ```
#
# The broad strokes to creating this list goes as follows:
#
# - use the command `os.listdir('maildir')` to see the folders in the mail directory
# - then use the command `os.listdir('maildir/allen-p')` to see the folder in Allen P's folder
# - then use the command `os.listdir('maildir/allen-p/inbox')` to see the contents in Allen P's inbox and collect the full file paths
# - you need to also collect all the files in both the inbox and sent_items folders for Allen P, do not track emails from the other folders
# - next move onto Arnold J!
# - next move onto Arora H!
# - ....
#
# Light bulbs should start going off in your head at this point about ways to solve this problem. This is a repeated process that needs to happen many many times. A for loop is the simplest way to solve a repetitive task. **Use for loops** to collect all 79,429 file paths into a single list.
#
# **Hint:** look up `os.path.join()` or f-strings if you are having trouble creating the appropriate argument for the `os.listdir()` command

# %% [markdown]
# In the following cell(s) produce the list of emails as directed and save the result to the object `list_email_paths`

# %%
import os.path
from os import path
list_emails=[]
directory = '/root/hw-3-assignment-prakhar7m/maildir'
for folder in os.listdir(directory):
    subdir=os.fsdecode(folder)
    inbox=os.path.join(directory, subdir, 'inbox')
    sent=os.path.join(directory, subdir, 'sent_items')
    if path.exists(inbox):
        for file in os.listdir(inbox):
            list_emails.append((os.path.join(inbox, file)))
    if path.exists(sent):
        for f2 in os.listdir(sent):
            list_emails.append((os.path.join(sent, f2)))
         # Do something
    #sent.append(os.path.join(directory, subdir, 'sent'))

# %% [markdown]
# In the following cell(s) print the first 10 items of the list as well as the length of the list

# %%
list_emails[0:10]
# Out:
# ['/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/395_',
#  '/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/197_',
#  '/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/278_',
#  '/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/100_',
#  '/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/179_',
#  '/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/1_',
#  '/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/89_',
#  '/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/377_',
#  '/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/10_',
#  '/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/458_']

# %%
len(list_emails)
# Out:
# 79430

# %%
list_emails.remove('/root/hw-3-assignment-prakhar7m/maildir/allen-p/inbox/.ipynb_checkpoints')

# %% [markdown]
# --------------------

# %% [markdown]
# ### Task 2: Read in one text email and parse out relevant information using a function (8 points)

# %% [markdown]
# Before you get to parallelizing, you need to build the function that will execute on every email in your list. The objective of this task is to build the function called `email_process()` which will take as an input the path of an email and output the following information in a dictionary:
#
# * Email of the sender
# * Email(s) of the recipient
# * Email timestamp
# * Email subject
# * Email body
#
# An example output from the function on the first email in Allen P's inbox looks like the following:
#
# ```
# {'from': 'heather.dunton@enron.com',
#  'to': 'k..allen@enron.com',
#  'timestamp': 'Fri, 7 Dec 2001 10:06:42 -0800 (PST)'
#  'subject': 'RE: West Position',
#  'body': ' \nPlease let me know if you still need Curve Shift.\n\nThanks,\nHeather\n -----Original Message-----\nFrom: \tAllen, Phillip K.  \nSent:\tFriday, December 07, 2001 5:14 AM\nTo:\tDunton, Heather\nSubject:\tRE: West Position\n\nHeather,\n\nDid you attach the file to this email?\n\n -----Original Message-----\nFrom: \tDunton, Heather  \nSent:\tWednesday, December 05, 2001 1:43 PM\nTo:\tAllen, Phillip K.; Belden, Tim\nSubject:\tFW: West Position\n\nAttached is the Delta position for 1/16, 1/30, 6/19, 7/13, 9/21\n\n\n -----Original Message-----\nFrom: \tAllen, Phillip K.  \nSent:\tWednesday, December 05, 2001 6:41 AM\nTo:\tDunton, Heather\nSubject:\tRE: West Position\n\nHeather,\n\nThis is exactly what we need.  Would it possible to add the prior day for each of the dates below to the pivot table.  In order to validate the curve shift on the dates below we also need the prior days ending positions.\n\nThank you,\n\nPhillip Allen\n\n -----Original Message-----\nFrom: \tDunton, Heather  \nSent:\tTuesday, December 04, 2001 3:12 PM\nTo:\tBelden, Tim; Allen, Phillip K.\nCc:\tDriscoll, Michael M.\nSubject:\tWest Position\n\n\nAttached is the Delta position for 1/18, 1/31, 6/20, 7/16, 9/24\n\n\n\n << File: west_delta_pos.xls >> \n\nLet me know if you have any questions.\n\n\nHeather'
#  }
# ```
#
# To process the raw text file, we recommend that you use the `email.parser.Parser()` function. Read documentation on it [here](https://docs.python.org/3/library/email.parser.html).
#
# The to field will need some cleaning. Remove any carriage returns, tabs, or spaces from the to field.
#
# It's OK that the email body is really messy right now. A future task is to clean it up.

# %% [markdown]
# In the following cell(s) produce the function `email_process()`

# %%
list_emails[0]
# Out:
# '/root/hw-3-assignment-prakhar7m/maildir/giron-d/inbox/395_'

# %%
def email_process(filepath):
    from email.parser import Parser
    final_dict ={}
    items = ["From", "To", "Subject", "Date"]
    data= open(filepath, encoding='latin-1').read()
    #print(data)
    email_parsed =Parser().parsestr(data, headersonly=False)     
    #print(email_message)
    """"for key, value in email_parsed.items(): 
        setattr(email_parsed,key,value)"""
    
    
    final_dict["From"]=email_parsed['From']
    final_dict["To"]=email_parsed['To']
    final_dict["Date"]=email_parsed['Date']
    final_dict["Subject"]=email_parsed['Subject']
    
    """for key, value in email_parsed.items(): 
        setattr(email_parsed,key,value)"""
        
    #print(email_parsed.Subject)
    
    """for key, value in email_parsed.items(): 
        if key in items:
            final_dict[key] = []
            final_dict[key].append(value)"""
            
    if email_parsed.is_multipart():
        for part in email_parsed.get_payload():
            final_dict["Body"] = (part.get_payload())
    else:
        final_dict["Body"] = (email_parsed.get_payload())
    
     
    
    return final_dict

# %% [markdown]
# ----------------

# %%
email_1= email_process('/root/hw-3-assignment-prakhar7m/maildir/allen-p/inbox/1_')

# %%
print(email_1)
# Out:
# {'From': 'heather.dunton@enron.com', 'To': 'k..allen@enron.com', 'Date': 'Fri, 7 Dec 2001 10:06:42 -0800 (PST)', 'Subject': 'RE: West Position', 'Body': ' \nPlease let me know if you still need Curve Shift.\n\nThanks,\nHeather\n -----Original Message-----\nFrom: \tAllen, Phillip K.  \nSent:\tFriday, December 07, 2001 5:14 AM\nTo:\tDunton, Heather\nSubject:\tRE: West Position\n\nHeather,\n\nDid you attach the file to this email?\n\n -----Original Message-----\nFrom: \tDunton, Heather  \nSent:\tWednesday, December 05, 2001 1:43 PM\nTo:\tAllen, Phillip K.; Belden, Tim\nSubject:\tFW: West Position\n\nAttached is the Delta position for 1/16, 1/30, 6/19, 7/13, 9/21\n\n\n -----Original Message-----\nFrom: \tAllen, Phillip K.  \nSent:\tWednesday, December 05, 2001 6:41 AM\nTo:\tDunton, Heather\nSubject:\tRE: West Position\n\nHeather,\n\nThis is exactly what we need.  Would it possible to add the prior day for each of the dates below to the pivot table.  In order to validate the curve shift on the dates below we also need the prior days ending positions.\n\nThank you,\n\nPhillip Allen\n\n -----Original Message-----\nFrom: \tDunton, Heather  \nSent:\tTuesday, December 04, 2001 3:12 PM\nTo:\tBelden, Tim; Allen, Phillip K.\nCc:\tDriscoll, Michael M.\nSubject:\tWest Position\n\n\nAttached is the Delta position for 1/18, 1/31, 6/20, 7/16, 9/24\n\n\n\n << File: west_delta_pos.xls >> \n\nLet me know if you have any questions.\n\n\nHeather'}

# %% [markdown]
# ### Task 3: Read in all emails using multiprocessing (8 points)

# %% [markdown]
# There are two ways to implement multiprocessing on a list of data:
#
# 1. **The vanilla approach to parallelization** involves getting a list of the items to process, then using the multiple worker processes to complete all the items in parallel like queue system. The list gets processes by workers until there are no items left.
# 2. **The splitting approach to parallelization** involves getting a list of items to process, splitting that list into a number of sublists, then split each sublist to a worker. Each worker then processes the sublist in serial.
#
# For more background on these two ideas, check out this useful [medium post](https://medium.com/idealo-tech-blog/parallelisation-in-python-an-alternative-approach-b2749b49a1e).

# %% [markdown]
# **If you are using a Windows machine (not in this lab)**, you will be unable to save your function in a cell and then run with multiprocesing. Instead, save two scripts `mail_functions_vanilla.py` and `mail_functions_split.py` with the functions needed for each approach. Import the module that you will execute in parallel by calling `import mail_functions_vanilla` and then calling a function within that module, just like you would any other module in python.

# %% [markdown]
# Use the `time` module to track the time taken for each approach.

# %% [markdown]
# In the following cell(s), implement the vanilla approach to parallelization to process all emails using `pool.map()`. Save the output list to an object called `out_vanilla`.

# %%
from multiprocessing import Pool
import time

# %%
starttime = time.time()
pool = Pool(10)
out_vanilla=[]
out_vanilla=pool.map(email_process, list_emails)
pool.close()
endtime = time.time()
print(f"Time taken {endtime-starttime} seconds")
# Out:
# Time taken 52.80142879486084 seconds

# %% [markdown]
# In the following cell(s), implement the splitting approach to parallelization to process all emails using `pool.map()`. Save the output list to an object called `out_split`.

# %%
from multiprocessing import pool
import time
starttime = time.time()
pool = Pool(10)
out_split=[]
out_split=pool.map(email_process, list_emails, 1000)
pool.close()
endtime = time.time()
print(f"Time taken {endtime-starttime} seconds")
# Out:
# Time taken 13.847573518753052 seconds

# %% [markdown]
# In the following cell(s), confirm that the results from each method are the same. If they are not, then figure out how to make them the same.

# %%
if len(out_vanilla)==len(out_split):
    print(True)
else:
    print(False)
# Out:
# True

# %%
import pandas as pd
df_emails=pd.DataFrame(columns=['From','To','Date','Subject','Body'], dtype=object)
df_emails.reset_index()
# Out:
# Empty DataFrame
# Columns: [index, From, To, Date, Subject, Body]
# Index: []

# %% [markdown]
# In the following cell(s), convert the list `out_split` to a Pandas DataFrame and save it as `df_emails`

# %%
for data in out_split:
    df_emails=df_emails.append(data, ignore_index=True)

# %%
df_emails.head()
# Out:
#                           From                                            To  \
# 0     patrick.tucker@enron.com  bryant.frihart@enron.com, c..giron@enron.com
# 1         dmoore21@charter.net                            c..giron@enron.com
# 2        lisa.kinsey@enron.com                            t..hodge@enron.com
# 3  deirdre.mccaffrey@enron.com                            c..giron@enron.com
# 4         greg.couch@enron.com                            c..giron@enron.com
#
#                                     Date  \
# 0  Wed, 21 Nov 2001 12:43:53 -0800 (PST)
# 1  Mon, 13 Aug 2001 04:05:04 -0700 (PDT)
# 2  Thu, 29 Nov 2001 08:56:03 -0800 (PST)
# 3  Wed, 23 Jan 2002 12:21:22 -0800 (PST)
# 4  Fri, 29 Jun 2001 12:04:12 -0700 (PDT)
#
#                                        Subject  \
# 0                  Wednesday's  Activity Recap
# 1                                         Kirk
# 2   FW: Immediate Suspension of Gas Deliveries
# 3  RE: Peoples Cash Flow 1-22-02 - Russell.xls
# 4                            FW: Life as a Guy
#
#                                                 Body
# 0  Jim @ Kaztex bought 20/d NBPL @ Harper on our ...
# 1  \nSo sorry that you and Kristi are having to g...
# 2  \n\n-----Original Message-----\nFrom: Lenart, ...
# 3  thanks - it all makes sense!! Scary\n\nDeirdre...
# 4  \n\n -----Original Message-----\nFrom: \tBaile...

# %%
df_emails['From'] =df_emails['From'].astype(str)

# %%
df_emails['To'] =df_emails['To'].astype(str)

# %% [markdown]
# ### Task 4: Find the most frequent emailers in the dataset (8 points)

# %% [markdown]
# We want to know which people sent or received the most emails in the dataset. Use your Pandas dataframe fields `to` and `from` to count the number of emails where an email address appears in the data.
#
# **You must use a dictionary** to keep track of the connections between email addresses. This will involve looping through each row and countering the dictionary up for each email instance found. For example, if we processed rows of the data and found that abc@enron.com sent one email to def@enron.com and ghi@enron.com, another sent email to jkl@enron.com as well as received an email from ghi@enron.com. This would result in a dictionary like so:
#
# ```
# {
#  'abc@enron.com' : 3,
#  'ghi@enron.com' : 2,
#  'def@enron.com' : 1,
#  'jkl@enron.com' : 1
# }
# ```
#
# Note that we are counting the email address whether it is the recipient or the sender of the email. It is certainly possible that both sides of the email conversation appears in the dataset, but it is OK to count that twice. The `To` field can contain multiple emails. You have to parse and count each email recipient separately!
#
# This process might require a lot of computing power to process every email! You must use `pool.map()` or another `multiprocessing` module function for the mapping part of the problem. The output will be a list of dictionaries like the example above. You will write a function to execute on a small chunk of the dataframe. After you have the list of dictionaries from each chunk, reduce them into a single dictionary.
#
# **BONUS:** 3 points - implement the same map and reduce operations leveraging pandas vectorized operations and groupby-summarize functions.
#
#
# **Hint:** break your dataframe into a list of smaller dataframes, and use that list to pass through `pool.map()`

# %% [markdown]
# Use the following cell(s) to answer this question:

# %% [markdown]
# In the following cell, save a dictionary with only the 20 email addresses with the most emails to the object `dict_top_addresses_sent`
#
# **Hint:** The top email address should be `'jeff.dasovich@enron.com'` with 2,624 emails (though a slightly different number if OK)

# %%
ecount=[]
for x in df_emails['To']:
    to_list = x.split(",")
    for y in to_list:
        ecount.append(y)

for x in df_emails['From']:
    ecount.append(x)

# %%
##From_list= df_emails['From'].tolist() 
len(ecount)
# Out:
# 540572

# %%
##

# %%
len(ecount)
# Out:
# 540572

# %%
substring = 'jeff.dasovich@enron.com'
for i in range(0,len(ecount)):
    if substring in ecount[i]:
        ecount[i] = substring

# %%
'''
from collections import Counter
freq=Counter(ecount)
print(freq)
'''
# Out:
# '\nfrom collections import Counter\nfreq=Counter(ecount)\nprint(freq)\n'

# %%
import numpy as np
res2=np.array_split(ecount,100)

# %%
def to_frequency_table(data):
    frequencytable = {}
    for key in data:
        if key in frequencytable:
            frequencytable[key] = frequencytable[key] + 1
        else:
            frequencytable[key] = 1
    return frequencytable

# %%
from multiprocessing import Pool

pool = Pool(8)
frequency = pool.map(to_frequency_table, res2)
pool.close()

# %%
##frequency[:10]

# %%
final_dict = {}
for x in frequency:
    for key, value in x.items():
        if key in final_dict:
            final_dict[key] += value
        else:
            final_dict[key] = value

# %%
final_dict['jeff.dasovich@enron.com']
# Out:
# 2624

# %% [markdown]
# ### Final Task: Run the following cell so your outputs can be checked for accuracy - this is a requirement

# %%
grading_dict = {'len_paths' : len(list_emails),
 'email_1' : email_1,
 'vanilla_split_match' : out_vanilla == out_split,
 'df_emails' : df_emails.head(20),
 'dict_top_email_addresses' : final_dict['jeff.dasovich@enron.com']
 }

import pickle
pickle.dump(grading_dict, open('grading_objects.pkl', 'wb'))
